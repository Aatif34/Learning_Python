# %% [markdown]
# <a href="https://colab.research.google.com/github/Aatif34/Learning_Python/blob/main/Copy%20of%20session-1-tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
print("Data", "Science", "Mentorship", "Program", "By", "CampusX", sep = "-")
# Out:
# Data-Science-Mentorship-Program-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
c = 73
f = (c/5)*9 + 32
print(f)
# Out:
# 163.4

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here
a = int(input("enter any munber"))
b = int(input("enter any munber"))
temp = a
a=b
b = temp
print ("after swaping (a,b): ", a, "," ,b)
# Out:
# enter any munber43
# enter any munber4
# after swaping (a,b):  4 , 43

# %% [markdown]
# Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# Write your code here
x = int(input("enter 1st absicsa"))
y = int(input("enter 1st ordinate"))
print("1st coordinate is: ", (x,y))
a = int(input("enter 1st absicsa"))
b = int(input("enter 1st ordinate"))
print("2nd coordinate is: ", (a,b))

distance = ((x-a)**2 +(y-b)**2)**0.5

print("euclidean distance between two coordinates will be: ", distance)
# Out:
# enter 1st absicsa2
# enter 1st ordinate3
# 1st coordinate is:  (2, 3)
# enter 1st absicsa5
# enter 1st ordinate7
# 2nd coordinate is:  (5, 7)
# euclidean distance between two coordinates will be:  5.0

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here
p = int(input("Enter Principle"))
r = int(input("Enter Rate of interest"))
t = int(input("Enter Time Period"))
Si = (p*r*t)/100

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
from IPython.core.compilerop import check_linecache_ipython
# Write your code here

heads = int(input("Enter number of heads: "))
legs = int(input("Enter number of legs: "))

for dogs in range(heads + 1):

  chicken = heads - dogs

  total_legs = 4*dogs + 2*chicken

  if total_legs == legs:
    print(f"number of dogs:  {dogs}")
    print(f"number of chicken: {chicken}")
# Out:
# Enter number of heads: 4
# Enter number of legs: 12
# number of dogs:  2
# number of chicken: 2

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code here
n = int(input("enter n: "))
sum = 0
for i in range(1, n+1):
  sum += i*i

print(f"sum of squares of first n natural numbers: {sum}")
# Out:
# enter n: 4
# sum of squares of first n natural numbers: 30

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here
a = int(input('Enter 1st term: '))
b = int(input('Enter 2nd term: '))
n = int(input('no of terms: '))
d = b-a
tn = a + (n-1)*d
print("nth term of the arithmetic series: ", tn)
# Out:
# Enter 1st term: 2
# Enter 2nd term: 4
# no of terms: 3
# nth term of the arithmetic series:  6

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here
n1 = int(input('Enter numerator of 1st fraction: '))
d1 = int(input('Enter Denominator of 1st fraction: '))
n2 = int(input('Enter numerator of 2nd fraction: '))
d2 = int(input('Enter Denominator of 2nd fraction: '))

if d1 == 0 or d2 == 0:
  print("Denominator should not be zero, enter another number ")
else:
  fraction_sum = (n1*d2 + n2*d1)/(d1*d2)
  print("sum of two fractions: ", fraction_sum)
# Out:
# Enter numerator of 1st fraction: 5
# Enter Denominator of 1st fraction: 4
# Enter numerator of 2nd fraction: 4
# Enter Denominator of 2nd fraction: 5
# sum of two fractions:  2.05

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
print("All Mesurements should be in meters(si units)")
H = int(input('Enter height of a milk tank: '))
L = int(input('Enter width of a milk tank: '))
B = int(input('Enter breadth of a milk tank: '))

h = int(input('Enter height of a glass: '))
r = int(input('Enter radius of a glass: '))

volume_tank = H*L*B
Volume_glass = (22/7)*r*r*h
no_of_glass = volume_tank // Volume_glass

print("number of glasse obtained: ", no_of_glass)
# Out:
# Enter height of a milk tank: 3
# Enter width of a milk tank: 4
# Enter breadth of a milk tank: 5
# Enter height of a glass: 1
# Enter radius of a glass: 7
# number of glasse obtained:  0.0
